# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f0bc3ed-9a17-495b-8ac5-5c76bc6c7e20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f0bc3ed-9a17-495b-8ac5-5c76bc6c7e20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
dataset = pd.read_csv('Proceesed_data_ - DeathTrafficAccidentInformation(2021) (1).csv')

# Extract the target variable (y)
y = dataset['부상자수'].values

# Extract the features (X)
X = dataset.drop(['부상자수'], axis=1).values

# Data preprocessing - Standardization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# Importing Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialize the Artificial Neural Network for regression
regressor = Sequential()

# Add the input layer and the first hidden layer
regressor.add(Dense(units=6, kernel_initializer='uniform', activation='relu', input_dim=X.shape[1]))

# Add a second hidden layer
regressor.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

# Add the output layer
regressor.add(Dense(units=1, kernel_initializer='uniform'))  # No activation function for regression

# Compile the ANN for regression
regressor.compile(optimizer='adam', loss='mean_squared_error')  # Use mean squared error for regression

# Fit the ANN to the Training set
history = regressor.fit(X_train, y_train, batch_size=10, epochs=100, validation_data=(X_test, y_test))

# Predicting the test results
y_pred = regressor.predict(X_test)

# Evaluate the model using a regression metric (e.g., Mean Absolute Error, Mean Squared Error, etc.)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# Epoch 1/100
# 226/226 [==============================] - 1s 4ms/step - loss: 3.6948 - val_loss: 0.9479
# Epoch 2/100
# 226/226 [==============================] - 0s 2ms/step - loss: 3.6106 - val_loss: 0.9146
# Epoch 3/100
# 226/226 [==============================] - 1s 2ms/step - loss: 3.5563 - val_loss: 0.9032
# Epoch 4/100
# 215/226 [===========================>..] - ETA: 0s - loss: 3.5404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-db6676ef6156> in <cell line: 44>()
#      42
#      43 # Fit the ANN to the Training set
# ---> 44 history = regressor.fit(X_train, y_train, batch_size=10, epochs=100, validation_data=(X_test, y_test))
#      45
#      46 # Predicting the test results
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix, accuracy_score

# Load your dataset
dataset = pd.read_csv('Proceesed_data_ - 사망교통사고정보(2021)(1).csv')

# Extract the target variable (y)
y = dataset['부상자수'].values

# Extract the features (X)
X = dataset.drop(['부상자수'], axis=1).values

# Data preprocessing - Standardization
sc = StandardScaler()
X = sc.fit_transform(X)

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# Initialize the Artificial Neural Network for regression
regressor = Sequential()

# Add the input layer and the first hidden layer
regressor.add(Dense(units=6, kernel_initializer='uniform', activation='relu', input_dim=X.shape[1]))

# Add a second hidden layer
regressor.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

# Add the output layer
regressor.add(Dense(units=1, kernel_initializer='uniform'))  # No activation function for regression

# Compile the ANN for regression
regressor.compile(optimizer='adam', loss='mean_squared_error')  # Use mean squared error for regression

# Fit the ANN to the Training set
regressor.fit(X_train, y_train, batch_size=10, epochs=100, verbose=0)  # Silent training

# Predicting the test results
y_pred = regressor.predict(X_test)

# Convert predictions to integers (assuming you want integer predictions)
y_pred = y_pred.astype(int)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c2ed542f9c97> in <cell line: 10>()
#       8
#       9 # Load your dataset
# ---> 10 dataset = pd.read_csv('Proceesed_data_ - 사망교통사고정보(2021)(1).csv')
#      11
#      12 # Extract the target variable (y)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix, accuracy_score

# Load your dataset
dataset = pd.read_csv('Proceesed_data_ - 사망교통사고정보(2021).csv')

# Extract the target variable (y)
y = dataset['부상자수'].values

# Extract the features (X)
X = dataset.drop(['부상자수'], axis=1).values

# Data preprocessing - Standardization
sc = StandardScaler()
X = sc.fit_transform(X)

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1, random_state=0)

# Initialize the Artificial Neural Network for regression
regressor = Sequential()

# Add the input layer and the first hidden layer
regressor.add(Dense(units=6, kernel_initializer='uniform', activation='relu', input_dim=X.shape[1]))

# Add a second hidden layer
regressor.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

# Add the output layer
regressor.add(Dense(units=1, kernel_initializer='uniform'))  # No activation function for regression

# Compile the ANN for regression
regressor.compile(optimizer='adam', loss='mean_squared_error')  # Use mean squared error for regression

# Fit the ANN to the Training set
regressor.fit(X_train, y_train, batch_size=10, epochs=100, verbose=0)  # Silent training

# Predicting the test results
y_pred = regressor.predict(X_test)

# Convert predictions to integers (assuming you want integer predictions)
y_pred = y_pred.astype(int)


# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Display predictions for each value
Count = 0
total_error = 0
for V in range(len(X)):
  prediction = clf.predict([X.iloc[V]])
  real_value = y.iloc[V]
  if prediction != real_value:
    total_error += abs(prediction - real_value)
    Count += 1

if Count != 0:
    print("Average error: ",total_error / Count)
else:
    print("No errors found.")
# Out:
# 1/1 [==============================] - 0s 52ms/step
# Accuracy: 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b98b7042540c> in <cell line: 58>()
#      57 total_error = 0
#      58 for V in range(len(X)):
# ---> 59   prediction = clf.predict([X.iloc[V]])
#      60   real_value = y.iloc[V]
#      61   if prediction != real_value:
#
# NameError: name 'clf' is not defined
